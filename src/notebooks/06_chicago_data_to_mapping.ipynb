# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

import pandas as pd
pd.set_option('display.max_columns', 30)

import requests

# %%
current_datetime = datetime.now() - relativedelta(months=2)

formatted_date = current_datetime.strftime("%Y-%m-%d")

url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{formatted_date}T00:00:00' AND trip_start_timestamp <= '{formatted_date}T23:59:59'&$limit=30000"

response = requests.get(url)

data = response.json()

# %%
len(data)
# Out:
# 14795

# %%
taxi_trips = pd.DataFrame(data)

# %%
taxi_trips.head()
# Out:
#                                     trip_id  \
# 0  9e8d7a1e364d9f4b0cf5bcb6759003066fdc34ac
# 1  f0e77c373ecdcbf984e5ec5dc9d07061af69cd9a
# 2  efb875e75459c88ff60ab0f01fd80494608fbd27
# 3  ea8e66c280961b6a853c3c424a1aa286e248b4df
# 4  e6fe9756e6fcbc0051e44976b213a052b7622ab5
#
#                                              taxi_id     trip_start_timestamp  \
# 0  cea53c687c3dd5ab8ad7483cc0003e4ea755d879919588...  2025-01-10T23:45:00.000
# 1  9946e42a2123fb60e2fa9c39ce15b11a5cfd39cd899460...  2025-01-10T23:45:00.000
# 2  8307cf9433f0293eee99c6944aeab484521d9cd9b1fce5...  2025-01-10T23:45:00.000
# 3  0b8a006f4b69afc94a10a09d153b509374fc0371fd9118...  2025-01-10T23:45:00.000
# 4  da3e1a4ae3869a45b431284672484905a694d6a7a08a05...  2025-01-10T23:45:00.000
#
#         trip_end_timestamp trip_seconds trip_miles pickup_community_area  \
# 0  2025-01-11T00:30:00.000         2040       19.1                    67
# 1  2025-01-11T00:15:00.000         1025      12.04                    49
# 2  2025-01-10T23:45:00.000            5          0                    24
# 3  2025-01-11T00:00:00.000          447       1.15                    77
# 4  2025-01-11T00:15:00.000         1154      11.16                    13
#
#   dropoff_community_area   fare tips  ... payment_type  \
# 0                      1     47    0  ...         Cash
# 1                     33  31.25    0  ...       Prcard
# 2                     24     18  3.7  ...  Credit Card
# 3                     77    6.5    0  ...         Cash
# 4                    NaN   28.5    0  ...       Prcard
#
#                         company pickup_centroid_latitude  \
# 0     Taxi Affiliation Services             41.775928827
# 1                  City Service             41.706587882
# 2                  City Service             41.901206994
# 3  Blue Ribbon Taxi Association               41.9867118
# 4                     Flash Cab             41.983636307
#
#   pickup_centroid_longitude  \
# 0             -87.666596265
# 1             -87.623366512
# 2             -87.676355989
# 3             -87.663416405
# 4             -87.723583185
#
#                             pickup_centroid_location  \
# 0  {'type': 'Point', 'coordinates': [-87.66659626...
# 1  {'type': 'Point', 'coordinates': [-87.62336651...
# 2  {'type': 'Point', 'coordinates': [-87.67635598...
# 3  {'type': 'Point', 'coordinates': [-87.66341640...
# 4  {'type': 'Point', 'coordinates': [-87.72358318...
#
#   dropoff_centroid_latitude dropoff_centroid_longitude  \
# 0              42.009622881              -87.670166857
# 1              41.857183858              -87.620334624
# 2              41.901206994              -87.676355989
# 3                41.9867118              -87.663416405
# 4                       NaN                        NaN
#
#                            dropoff_centroid_location pickup_census_tract  \
# 0  {'type': 'Point', 'coordinates': [-87.67016685...                 NaN
# 1  {'type': 'Point', 'coordinates': [-87.62033462...                 NaN
# 2  {'type': 'Point', 'coordinates': [-87.67635598...                 NaN
# 3  {'type': 'Point', 'coordinates': [-87.66341640...                 NaN
# 4                                                NaN                 NaN
#
#   dropoff_census_tract
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 23 columns]

# %%
taxi_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14795 entries, 0 to 14794
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     14795 non-null  object
#  1   taxi_id                     14795 non-null  object
#  2   trip_start_timestamp        14795 non-null  object
#  3   trip_end_timestamp          14795 non-null  object
#  4   trip_seconds                14795 non-null  object
#  5   trip_miles                  14795 non-null  object
#  6   pickup_community_area       14263 non-null  object
#  7   dropoff_community_area      13322 non-null  object
#  8   fare                        14766 non-null  object
#  9   tips                        14766 non-null  object
#  10  tolls                       14766 non-null  object
#  11  extras                      14766 non-null  object
#  12  trip_total                  14766 non-null  object
#  13  payment_type                14795 non-null  object
#  14  company                     14795 non-null  object
#  15  pickup_centroid_latitude    14268 non-null  object
#  16  pickup_centroid_longitude   14268 non-null  object
#  17  pickup_centroid_location    14268 non-null  object
#  18  dropoff_centroid_latitude   13409 non-null  object
#  19  dropoff_centroid_longitude  13409 non-null  object
#  20  dropoff_centroid_location   13409 non-null  object
#  21  pickup_census_tract         5215 non-null   object
#  22  dropoff_census_tract        5014 non-null   object
# dtypes: object(23)
# memory usage: 2.6+ MB

# %%
taxi_trips.describe()
# Out:
#                                          trip_id  \
# count                                      14795
# unique                                     14795
# top     5b8a323faa4c41b4665b42a95f5dee65389db26b
# freq                                           1
#
#                                                   taxi_id  \
# count                                               14795
# unique                                               1966
# top     c34d6347f812df0e22ee1a907881bffff574dab3839a95...
# freq                                                   37
#
#            trip_start_timestamp       trip_end_timestamp trip_seconds  \
# count                     14795                    14795        14795
# unique                       96                      106         3033
# top     2025-01-10T18:30:00.000  2025-01-10T18:30:00.000          360
# freq                        300                      308          156
#
#        trip_miles pickup_community_area dropoff_community_area   fare   tips  \
# count       14795                 14263                  13322  14766  14766
# unique       2183                    77                     77   1549    905
# top             0                     8                      8      9      0
# freq         1141                  3264                   3344    866   8385
#
#         ... payment_type    company pickup_centroid_latitude  \
# count   ...        14795      14795                    14268
# unique  ...            7         36                      142
# top     ...  Credit Card  Flash Cab             41.899602111
# freq    ...         4489       3322                     1695
#
#        pickup_centroid_longitude  \
# count                      14268
# unique                       142
# top                -87.633308037
# freq                        1695
#
#                                  pickup_centroid_location  \
# count                                               14268
# unique                                                142
# top     {'type': 'Point', 'coordinates': [-87.63330803...
# freq                                                 1695
#
#        dropoff_centroid_latitude dropoff_centroid_longitude  \
# count                      13409                      13409
# unique                       166                        166
# top                 41.899602111              -87.633308037
# freq                        1448                       1448
#
#                                 dropoff_centroid_location pickup_census_tract  \
# count                                               13409                5215
# unique                                                166                  67
# top     {'type': 'Point', 'coordinates': [-87.63330803...         17031980000
# freq                                                 1448                 907
#
#        dropoff_census_tract
# count                  5014
# unique                   97
# top             17031839100
# freq                    759
#
# [4 rows x 23 columns]

# %%
taxi_trips[taxi_trips["fare"].isna()].sample(5)
# Out:
#                                        trip_id  \
# 7432  7c2ac37f2723d9eceae71089ed39c9108a85f6b5
# 1230  538bc02aaee44c4aea67589350f8796c73f8823c
# 1940  719588d4243564b1357d2a2da047c880b791d0a1
# 3458  ffc44402c22cc3e3c898b5669202d4d94c37fba7
# 5268  54a477d6817477d801e3e046a7330236c51efbb3
#
#                                                 taxi_id  \
# 7432  2407ff99e367ceb469a8cc6663e6ad6ec51fb0f401d370...
# 1230  180309cc29892cd16348ef74d7dd6f33af87e585a29b62...
# 1940  d786258c399e3cb198dcba48a1626465b7e02e1b6d8df2...
# 3458  27f4e362035594e6144066180cd9f740961885b33231bd...
# 5268  18c20740c9cbe78a07c7bef21fd4dd4035fa01fb10f186...
#
#          trip_start_timestamp       trip_end_timestamp trip_seconds  \
# 7432  2025-01-10T14:15:00.000  2025-01-10T14:30:00.000         1662
# 1230  2025-01-10T21:00:00.000  2025-01-10T21:45:00.000         2912
# 1940  2025-01-10T19:45:00.000  2025-01-10T19:45:00.000            3
# 3458  2025-01-10T18:00:00.000  2025-01-10T18:15:00.000          839
# 5268  2025-01-10T16:30:00.000  2025-01-10T16:45:00.000         1207
#
#      trip_miles pickup_community_area dropoff_community_area fare tips  ...  \
# 7432      16.97                    76                     28  NaN  NaN  ...
# 1230       1.11                    56                     56  NaN  NaN  ...
# 1940          0                    76                     76  NaN  NaN  ...
# 3458       2.22                     4                     16  NaN  NaN  ...
# 5268       5.71                     8                      5  NaN  NaN  ...
#
#      payment_type                       company pickup_centroid_latitude  \
# 7432         Cash          Chicago Independents              41.97907082
# 1230         Cash  Taxicab Insurance Agency Llc              41.79259236
# 1940         Cash  Taxicab Insurance Agency Llc              41.97907082
# 3458       Mobile                     Flash Cab             41.975170943
# 5268         Cash                      Sun Taxi             41.899602111
#
#      pickup_centroid_longitude  \
# 7432             -87.903039661
# 1230             -87.769615453
# 1940             -87.903039661
# 3458             -87.687515515
# 5268             -87.633308037
#
#                                pickup_centroid_location  \
# 7432  {'type': 'Point', 'coordinates': [-87.90303966...
# 1230  {'type': 'Point', 'coordinates': [-87.76961545...
# 1940  {'type': 'Point', 'coordinates': [-87.90303966...
# 3458  {'type': 'Point', 'coordinates': [-87.68751551...
# 5268  {'type': 'Point', 'coordinates': [-87.63330803...
#
#      dropoff_centroid_latitude dropoff_centroid_longitude  \
# 7432              41.879255084              -87.642648998
# 1230               41.79259236              -87.769615453
# 1940               41.97907082              -87.903039661
# 3458              41.953582125               -87.72345239
# 5268              41.947791586              -87.683834942
#
#                               dropoff_centroid_location pickup_census_tract  \
# 7432  {'type': 'Point', 'coordinates': [-87.64264899...         17031980000
# 1230  {'type': 'Point', 'coordinates': [-87.76961545...                 NaN
# 1940  {'type': 'Point', 'coordinates': [-87.90303966...         17031980000
# 3458  {'type': 'Point', 'coordinates': [-87.72345239...                 NaN
# 5268  {'type': 'Point', 'coordinates': [-87.68383494...                 NaN
#
#      dropoff_census_tract
# 7432          17031281900
# 1230                  NaN
# 1940          17031980000
# 3458                  NaN
# 5268                  NaN
#
# [5 rows x 23 columns]
